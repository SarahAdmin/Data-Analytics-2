# %%
import pandas as pd

# %%
df = pd.read_csv('HMCTS_MI_output_accessible_Nov_25.csv',encoding='latin-1')

# %%
df.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_f9657_row0_col1 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_f9657_row0_col2 {
#   background-color: #edebf4;
#   color: #000000;
# }
# #T_f9657_row0_col3, #T_f9657_row0_col53, #T_f9657_row6_col33, #T_f9657_row8_col37 {
#   background-color: #4c1888;
#   color: #f1f1f1;
# }
# #T_f9657_row0_col4, #T_f9657_row2_col20, #T_f9657_row2_col61, #T_f9657_row5_col10, #T_f9657_row11_col64, #T_f9657_row12_col42 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_f9657_row0_col5, #T_f9657_row1_col59, #T_f9657_row3_col14, #T_f9657_row3_col38, #T_f9657_row4_col4, #T_f9657_row5_col59, #T_f9657_row7_col14, #T_f9657_row8_col38, #T_f9657_row8_col54 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_f9657_row0_col6, #T_f9657_row2_col56, #T_f9657_row6_col62, #T_f9657_row7_col56, #T_f9657_row9_col20 {
#   background-color: #b8b8d9;
#   color: #000000;
# }
# ...

# %% [markdown]
# The results throughout Nov 24 - Nov 25 shows the number of claims, laws and cases.
# Key shown on the HMCTS results has shades of purple. E.g., The Darkest colour represents the maximum number and the lighest colour represents the minimum number.

# %%
df1 = df.drop(columns='Month',axis=1)

# %%
final_df1 = df1.corr(method='pearson')

# %%
final_df1.style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# The results of HMCTS has correctlation (Pearson method) to show these negative and postive numbers of claims, laws, divorces and cases.
